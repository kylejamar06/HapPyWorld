# %%
#  Importing Dependencies

import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#  Linking in csv files sources using the OS Module

csvpath_2015 = os.path.join('Resources', '2015.csv')
csvpath_2016 = os.path.join('Resources', '2016.csv')
csvpath_2017 = os.path.join('Resources', '2017.csv')
csvpath_2018 = os.path.join('Resources', '2018.csv')
csvpath_2019 = os.path.join('Resources', '2019.csv')

# %%
#  Loading CSV Data from data files using CSV Module .read_csv Method

csv_2015 = pd.read_csv(csvpath_2015)
csv_2016 = pd.read_csv(csvpath_2016)
csv_2017 = pd.read_csv(csvpath_2017)
csv_2018 = pd.read_csv(csvpath_2018)
csv_2019 = pd.read_csv(csvpath_2019)

# %%
#  Creating new dataframes for the five underlying datasets, insuring column structure and 
#  naming conventions are congruent.  Also drops unnecessary columns some datasets include.  Also
#  adding a year column for later grouped analysis calcs.

# %%
csv_2019_restructured = csv_2019
csv_2019_restructured["Year"] = 2019
csv_2019_restructured.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %%
csv_2018_restructured = csv_2018
csv_2018_restructured["Year"] = 2018
csv_2018_restructured.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / Fix 2017 Data

csv_2017_restructured = csv_2017[["Happiness.Rank",
                                  "Country",
                                  "Happiness.Score",
                                  "Economy..GDP.per.Capita.",
                                  "Family",
                                  "Health..Life.Expectancy.",
                                  "Freedom",
                                  "Generosity",
                                  "Trust..Government.Corruption."]]

csv_2017_restructured = csv_2017_restructured.rename(columns={"Happiness.Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness.Score": "Score",
                                      "Economy..GDP.per.Capita.": "GDP per capita",
                                      "Family": "Social support",
                                      "Health..Life.Expectancy.": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust..Government.Corruption.": "Perceptions of corruption"})
csv_2017_restructured["Year"] = 2017
csv_2017_restructured.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1            Norway  7.537        1.616463        1.533524
# 1             2           Denmark  7.522        1.482383        1.551122
# 2             3           Iceland  7.504        1.480633        1.610574
# 3             4       Switzerland  7.494        1.564980        1.516912
# 4             5           Finland  7.469        1.443572        1.540247
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                 0.796667                      0.635423    0.362012
# 1                 0.792566                      0.626007    0.355280
# 2                 0.833552                      0.627163    0.475540
# 3                 0.858131                      0.620071    0.290549
# 4                 0.809158                      0.617951    0.245483
#
#    Perceptions of corruption  Year
# 0                   0.315964  2017
# 1                   0.400770  2017
# ...

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / fix 2016 Data

csv_2016_restructured = csv_2016[["Happiness Rank",
                                 "Country",
                                  "Happiness Score",
                                  "Economy (GDP per Capita)",
                                  "Family",
                                  "Health (Life Expectancy)",
                                  "Freedom",
                                  "Generosity",
                                  "Trust (Government Corruption)"]]

csv_2016_restructured = csv_2016_restructured.rename(columns={"Happiness Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness Score": "Score",
                                      "Economy (GDP per Capita)": "GDP per capita",
                                      "Family": "Social support",
                                      "Health (Life Expectancy)": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust (Government Corruption)": "Perceptions of corruption"})
csv_2016_restructured["Year"] = 2016
csv_2016_restructured.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Denmark  7.526         1.44178         1.16374
# 1             2       Switzerland  7.509         1.52733         1.14524
# 2             3           Iceland  7.501         1.42666         1.18326
# 3             4            Norway  7.498         1.57744         1.12690
# 4             5           Finland  7.413         1.40598         1.13464
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.79504                       0.57941     0.36171
# 1                  0.86303                       0.58557     0.28083
# 2                  0.86733                       0.56624     0.47678
# 3                  0.79579                       0.59609     0.37895
# 4                  0.81091                       0.57104     0.25492
#
#    Perceptions of corruption  Year
# 0                    0.44453  2016
# 1                    0.41203  2016
# ...

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / fix 2015 Data

csv_2015_restructured = csv_2015[["Happiness Rank",
                                 "Country",
                                  "Happiness Score",
                                  "Economy (GDP per Capita)",
                                  "Family",
                                  "Health (Life Expectancy)",
                                  "Freedom",
                                  "Generosity",
                                  "Trust (Government Corruption)"]]

csv_2015_restructured = csv_2015_restructured.rename(columns={"Happiness Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness Score": "Score",
                                      "Economy (GDP per Capita)": "GDP per capita",
                                      "Family": "Social support",
                                      "Health (Life Expectancy)": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust (Government Corruption)": "Perceptions of corruption"})
csv_2015_restructured["Year"] = 2015
csv_2015_restructured.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1       Switzerland  7.587         1.39651         1.34951
# 1             2           Iceland  7.561         1.30232         1.40223
# 2             3           Denmark  7.527         1.32548         1.36058
# 3             4            Norway  7.522         1.45900         1.33095
# 4             5            Canada  7.427         1.32629         1.32261
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.94143                       0.66557     0.29678
# 1                  0.94784                       0.62877     0.43630
# 2                  0.87464                       0.64938     0.34139
# 3                  0.88521                       0.66973     0.34699
# 4                  0.90563                       0.63297     0.45811
#
#    Perceptions of corruption  Year
# 0                    0.41978  2015
# 1                    0.14145  2015
# ...

# %%
#  Merging multi-year datasets together
individual_datasets = [csv_2015_restructured,
                       csv_2016_restructured,
                       csv_2017_restructured,
                       csv_2018_restructured,
                       csv_2019_restructured]

combined_data = pd.concat(individual_datasets)
combined_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1       Switzerland  7.587         1.39651         1.34951
# 1             2           Iceland  7.561         1.30232         1.40223
# 2             3           Denmark  7.527         1.32548         1.36058
# 3             4            Norway  7.522         1.45900         1.33095
# 4             5            Canada  7.427         1.32629         1.32261
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.94143                       0.66557     0.29678
# 1                  0.94784                       0.62877     0.43630
# 2                  0.87464                       0.64938     0.34139
# 3                  0.88521                       0.66973     0.34699
# 4                  0.90563                       0.63297     0.45811
#
#    Perceptions of corruption  Year
# 0                    0.41978  2015
# 1                    0.14145  2015
# ...

# %%
# Export to review in Excel
# combined_data.to_csv(r'C:\Users\simon\OneDrive\Desktop\combined_data.csv', index = False)

# %%
year_pivot = combined_data.groupby(["Year"]).mean()
year_pivot

#  Analysis ideas:  We can make some observations regarding the average 'weight' of each happiness 
#  factor over the five year timeline.  i.e., What areas were valued higher than others over time?
# Out:
#       Overall rank     Score  GDP per capita  Social support  \
# Year
# 2015     79.493671  5.375734        0.846137        0.991046
# 2016     78.980892  5.382185        0.953880        0.793621
# 2017     78.000000  5.354019        0.984718        1.188898
# 2018     78.500000  5.375917        0.891449        1.213237
# 2019     78.500000  5.407096        0.905147        1.208814
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# Year
# 2015                 0.630259                      0.428615    0.237296
# 2016                 0.557619                      0.370994    0.242635
# 2017                 0.551341                      0.408786    0.246883
# 2018                 0.597346                      0.454506    0.181006
# 2019                 0.725244                      0.392571    0.184846
#
#       Perceptions of corruption
# Year
# 2015                   0.143422
# 2016                   0.137624
# 2017                   0.123120
# ...

# %%
#  Graph 1: Line graphs plotting changes over time.
gdp_line_df = pd.DataFrame(combined_data["Year"],combined_data["GDP per capita"])
gdp_line_df.head()
# p_df = pd.DataFrame({"class": [1,1,2,2,1], "a": [2,3,2,3,2]})
# fig, ax = plt.subplots(figsize=(8,6))
# bp = p_df.groupby('class').plot(kind='kde', ax=ax)



# x_axis = year_pivot(["Year"])
# line_GDP = year_pivot("GDP per capita")
# plt.plot(x_axis, line_GDP)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-bb6aff071abf> in <module>
#       1 #  Graph 1: Line graphs plotting changes over time.
# ----> 2 gdp_line_df = pd.DataFrame(combined_data["Year"],combined_data["GDP per capita"])
#       3 gdp_line_df.head()
#       4 # p_df = pd.DataFrame({"class": [1,1,2,2,1], "a": [2,3,2,3,2]})
#       5 # fig, ax = plt.subplots(figsize=(8,6))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     493                 mgr = init_dict(data, index, columns, dtype=dtype)
#     494             elif getattr(data, "name", None) is not None:
# --> 495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
#     497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# ...

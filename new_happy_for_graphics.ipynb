# %%
#Dependencies

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px # for visualization 
import os
import plotly.graph_objects as go
from scipy.stats import linregress
import scipy.stats as sts
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-428ab805eef1> in <module>
#       3 import numpy as np # linear algebra
#       4 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ----> 5 import plotly.express as px # for visualization
#       6 import os
#       7 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Import & compare file heads of our various CSVs. We'll use 2019.csv as our template and create new
# dataframes of off the rest to ensure the data is congruent.

csvpath_2015 = os.path.join('Resources', '2015.csv')
csvpath_2016 = os.path.join('Resources', '2016.csv')
csvpath_2017 = os.path.join('Resources', '2017.csv')
csvpath_2018 = os.path.join('Resources', '2018.csv')
csvpath_2019 = os.path.join('Resources', '2019.csv')

csv_2015 = pd.read_csv(csvpath_2015)
csv_2015.head()

# %%
csv_2016 = pd.read_csv(csvpath_2016)
csv_2016.head()

# %%
csv_2017 = pd.read_csv(csvpath_2017)
csv_2017.head()

# %%
csv_2016 = pd.read_csv(csvpath_2016)

# %%
csv_2017 = pd.read_csv(csvpath_2017)

# %%
csv_2018 = pd.read_csv(csvpath_2018)

# %%
csv_2019 = pd.read_csv(csvpath_2019)

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / Fix 2017 Data

csv_2017_restructured = csv_2017[["Happiness.Rank",
                                  "Country",
                                  "Happiness.Score",
                                  "Economy..GDP.per.Capita.",
                                  "Family",
                                  "Health..Life.Expectancy.",
                                  "Freedom",
                                  "Generosity",
                                  "Trust..Government.Corruption."]]

csv_2017_restructured = csv_2017_restructured.rename(columns={"Happiness.Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness.Score": "Score",
                                      "Economy..GDP.per.Capita.": "GDP per capita",
                                      "Family": "Social support",
                                      "Health..Life.Expectancy.": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust..Government.Corruption.": "Perceptions of corruption"})

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / fix 2016 Data

csv_2016_restructured = csv_2016[["Happiness Rank",
                                 "Country",
                                  "Happiness Score",
                                  "Economy (GDP per Capita)",
                                  "Family",
                                  "Health (Life Expectancy)",
                                  "Freedom",
                                  "Generosity",
                                  "Trust (Government Corruption)"]]

csv_2016_restructured = csv_2016_restructured.rename(columns={"Happiness Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness Score": "Score",
                                      "Economy (GDP per Capita)": "GDP per capita",
                                      "Family": "Social support",
                                      "Health (Life Expectancy)": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust (Government Corruption)": "Perceptions of corruption"})

# %%
# 2019 & 2018 datasets are the same in structure & column naming convention.  Restructure / Rename
# datasets from 2015 - 2017.

# Convert / fix 2015 Data

csv_2015_restructured = csv_2015[["Happiness Rank",
                                 "Country",
                                  "Happiness Score",
                                  "Economy (GDP per Capita)",
                                  "Family",
                                  "Health (Life Expectancy)",
                                  "Freedom",
                                  "Generosity",
                                  "Trust (Government Corruption)"]]

csv_2015_restructured = csv_2015_restructured.rename(columns={"Happiness Rank": "Overall rank",
                                      "Country": "Country or region",
                                      "Happiness Score": "Score",
                                      "Economy (GDP per Capita)": "GDP per capita",
                                      "Family": "Social support",
                                      "Health (Life Expectancy)": "Healthy life expectancy",
                                      "Freedom": "Freedom to make life choices",
                                      "Generosity": "Generosity",
                                      "Trust (Government Corruption)": "Perceptions of corruption"})

# %%
#Add new "Year" column to each csv.
csv_2019["Year"] = 2019
csv_2018["Year"] = 2018
csv_2017_restructured["Year"] = 2017
csv_2016_restructured["Year"] = 2016
csv_2015_restructured["Year"] = 2015

# %%
#Combine 2015-2019 data into one csv.
csv_years_combined = csv_2015_restructured.append(csv_2016_restructured)
csv_years_combined = csv_years_combined.append(csv_2017_restructured)
csv_years_combined = csv_years_combined.append(csv_2018)
csv_years_combined = csv_years_combined.append(csv_2019)
csv_years_combined

#value_count_country = csv_years_combined["Country or region"].value_counts()
#value_count_country.tail(30)

# #csv_years_combined.groupby('Country or region').filter(lambda x : len(x)>4)

# counts = csv_years_combined['Country or region'].value_counts()
# #counts

# less_than_five = csv_years_combined.loc[csv_years_combined['Country or region'].isin(counts[counts < 5].index)]
# less_than_five

# #filtered data that excludes countries not in all datasets
# csv_years_combined.drop(less_than_five)
# csv_years_combined

    

# #csv_year_combined_df= csv_years_combined[csv_years_combined.groupby('Country or region')['Country or region'].transform(value_count_country) ==5]
# #csv_year_combined_df

# %%
#groupby year to make df with year avg for all countries

csv_4me = csv_years_combined.groupby("Year")
csv_4me.mean()

avg_df = csv_4me.mean()
avg_df

# %%
#line graph with score 

x_values= avg_df.index
y_values=avg_df["Score"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(5.2,5.6)
plt.title("Avg Happiness Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Happiness Score", labelpad=10, fontsize= 14)


#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="green")
plt.show()

# %%
#line graph with score 

x_values= avg_df.index
y_values=avg_df["GDP per capita"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.6, 1.2)
plt.title("Avg GDP per capita Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("GDP per capita Score", labelpad=10, fontsize= 14)

#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black")
plt.show()

# %%
#line graph with score 

x_values= avg_df.index
y_values=avg_df["Social support"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.5, 1.5)
plt.title("Avg Social Support Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Social Support Score", labelpad=10, fontsize= 14)

#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="red")
plt.show()

# %%
x_values= avg_df.index
y_values=avg_df["Healthy life expectancy"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.45,.8)
plt.title("Avg Healthy Life Expectancy Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Healthy Life Expectancy Score", labelpad=10, fontsize= 14)


#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="orange")
plt.show()

# %%
x_values= avg_df.index
y_values=avg_df["Freedom to make life choices"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.3, .55)
plt.title("Avg Freedom Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Freedom Score", labelpad=10, fontsize= 14)


#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="purple")
plt.show()

# %%
x_values= avg_df.index
y_values=avg_df["Generosity"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.1, .32)
plt.title("Avg Generosity Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Generosity Score", labelpad=10, fontsize= 14)


#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="brown")
plt.show()

# %%
x_values= avg_df.index
y_values=avg_df["Perceptions of corruption"]

#formatting
plt.figure(figsize=(10,7))
plt.ylim(.1, .16)
plt.title("Avg Perception of Corruption Score of all Countries (2015-2019)", pad=15, fontsize=14)
plt.xlabel("Years", labelpad=10, fontsize= 14)
plt.ylabel("Perception of Corruption Score", labelpad=10, fontsize= 14)


#plot and show
plt.plot(x_values, y_values, marker=".", mew="5", mec="black", color="aqua")
plt.show()

# %%
#import happy_region df so we can merge and make region column

csvpath_region = os.path.join('happy_regions.csv')
csv_happy_regions = pd.read_csv(csvpath_region)

#lets take out just country and region columns
new_region_df = csv_happy_regions[["Country", "Region"]]

#rename column so it matches with the newly structured csv below
new_region_df = new_region_df.rename(columns={"Country": "Country or region"})

# %%
#groupby country so we can have avgs for each country per year

csv_4me = csv_years_combined.groupby("Country or region")
csv_4me.mean()

country_sums = csv_4me.mean()
country_sums

#let's merge df with region category with df we created
merged_country_sum = pd.merge(country_sums, new_region_df, on="Country or region")
sorted_df = merged_country_sum.sort_values(by=["Score"], ascending=False)
sorted_df.head(20)

del sorted_df["Year"]
del sorted_df["Region"]
del sorted_df["Overall rank"]

sorted_df = sorted_df.reset_index()

del sorted_df["index"]
sorted_df.index = np.arange(1, len(sorted_df) + 1)

sorted_df.head(20)

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Score"]
y_values = merged_country_sum["GDP per capita"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg GDP per Capita Score (2015-2019)") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='GDP per Capita Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Social support"]
y_values = merged_country_sum["Score"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg Social Support Score (2015-2019)",
                 trendline="ols") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='Social Support Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Score"]
y_values = merged_country_sum["Healthy life expectancy"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg Healthy Life Expectancy Score (2015-2019)") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='Healthy Life Expectancy Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Score"]
y_values = merged_country_sum["Freedom to make life choices"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg Freedom Score (2015-2019)") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='Freedom to Make Life Choices Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Score"]
y_values = merged_country_sum["Generosity"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg Generosity Score (2015-2019)") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='Generosity Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()

# %%
#country avg over all datasets

#establish x and y values
x_values = merged_country_sum["Score"]
y_values = merged_country_sum["Perceptions of corruption"]

#px.scatter
fig = px.scatter(merged_country_sum, x_values, y_values, color="Region", hover_name="Country or region", 
                 range_x=[0,8], title="Avg Happiness Score compared to Avg Corruption Score (2015-2019)") # use trendline="ols" to see all lin reg equations

#set axes labels
fig.update_xaxes(title_text='Happiness Score')
fig.update_yaxes(title_text='Perception of Corruption Score')

#formatting
#marker size and colors
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1, 
                                        color='DarkSlateGrey')))


#linear regression
#use linregress from dependencies to inplement linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#print out all variables calculated above (rvalue, pvalue...)
print(f"slope:{round(slope, 2)}")
print(f"intercept:{round(intercept,2)}")
res = sts.linregress(x_values, y_values)
print(f"R-squared: {res.rvalue**2:.4f}")


#print out line eq for reference
line_eq = (f"y={round(slope, 2)}x + {round(intercept, 2)}")
print(line_eq)

fig.show()
